# %%
'''Visualization of the filters of VGG16, via gradient ascent in input space.

This script can run on CPU in a few minutes (with the TensorFlow backend).

Results example: http://i.imgur.com/4nj4KjN.jpg
'''
from __future__ import print_function
from scipy.misc import imsave
import numpy as np
import time
from keras.applications import vgg16
from keras import backend as K
from model import alexnet
import scipy.misc
import time
# dimensions of the generated pictures for each filter.
img_width = 128
img_height = 128

# the name of the layer we want to visualize
# (see model definition at keras/applications/vgg16.py)
layer_name = 'conv_5'

# util function to convert a tensor into a valid image


def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    if K.image_dim_ordering() == 'th':
        x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# build the VGG16 network with ImageNet weights
model = alexnet("alex_finetune567_aug_weights1.h5", nb_class=100)
print('Model loaded.')

model.summary()

# this is the placeholder for the input images
input_img = model.input

# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers[1:]])


def normalize(x):
    # utility function to normalize a tensor by its L2 norm
    return x / (K.sqrt(K.mean(K.square(x))) + 1e-5)


kept_filters = []
for filter_index in range(0, 200):
    # we only scan through the first 200 filters,
    # but there are actually 512 of them
    print('Processing filter %d' % filter_index)
    start_time = time.time()

    # we build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    if K.image_dim_ordering() == 'th':
        loss = K.mean(layer_output[:, filter_index, :, :])
    else:
        loss = K.mean(layer_output[:, :, :, filter_index])

    # we compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads = normalize(grads)

    # this function returns the loss and grads given the input picture
    iterate = K.function([input_img], [loss, grads])

    # step size for gradient ascent
    step = 1.

    # we start from a gray image with some random noise
    if K.image_dim_ordering() == 'th':
        #input_img_data = np.random.random((1, 3, img_width, img_height))
        input_img_data = scipy.misc.imresize(scipy.misc.imread("../dataset/food10/AisKacang/AisKacang (2).jpg"), (img_width,img_height)) 
        input_img_data = input_img_data.transpose((2, 0, 1))
        input_img_data = np.expand_dims(input_img_data, axis=0)
        
        #(1,128,128,3)
        
    else:
        input_img_data = np.random.random((1, img_width, img_height, 3))
    input_img_data = (input_img_data - 0.5) * 20 + 128
    
    # we run gradient ascent for 20 steps
    for i in range(2000):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step

        #print('Current loss value:', loss_value)
        if loss_value <= 0.:
            # some filters get stuck to 0, we can skip them
            break

    # decode the resulting input image
    if loss_value > 0:
        img = deprocess_image(input_img_data[0])
        kept_filters.append((img, loss_value))
    end_time = time.time()
    print('Filter %d processed in %ds' % (filter_index, end_time - start_time))

# we will stich the best 64 filters on a 8 x 8 grid.
n = 8

# the filters that have the highest loss are assumed to be better-looking.
# we will only keep the top 64 filters.
kept_filters.sort(key=lambda x: x[1], reverse=True)
kept_filters = kept_filters[:n * n]

# build a black picture with enough space for
# our 8 x 8 filters of size 128 x 128, with a 5px margin in between
margin = 5
width = n * img_width + (n - 1) * margin
height = n * img_height + (n - 1) * margin
stitched_filters = np.zeros((width, height, 3))

# fill the picture with our saved filters
for i in range(n):
    for j in range(n):
        img, loss = kept_filters[i * n + j]
        stitched_filters[(img_width + margin) * i: (img_width + margin) * i + img_width,
                         (img_height + margin) * j: (img_height + margin) * j + img_height, :] = img

# save the result to disk

imsave('foodstitched_filters_%dx%d.png' % (n, n), stitched_filters)
# Out:
# Model loaded.
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_11 (InputLayer)            (None, 3, 227, 227)   0
# ____________________________________________________________________________________________________
# conv_1 (Convolution2D)           (None, 96, 55, 55)    34944       input_11[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_21 (MaxPooling2D)   (None, 96, 27, 27)    0           conv_1[0][0]
# ____________________________________________________________________________________________________
# convpool_1 (Lambda)              (None, 96, 27, 27)    0           maxpooling2d_21[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_41 (ZeroPadding2D) (None, 96, 31, 31)    0           convpool_1[0][0]
# ____________________________________________________________________________________________________
# lambda_71 (Lambda)               (None, 48, 31, 31)    0           zeropadding2d_41[0][0]
# ____________________________________________________________________________________________________
# lambda_72 (Lambda)               (None, 48, 31, 31)    0           zeropadding2d_41[0][0]
# ____________________________________________________________________________________________________
# conv_2_1 (Convolution2D)         (None, 128, 27, 27)   153728      lambda_71[0][0]
# ____________________________________________________________________________________________________
# conv_2_2 (Convolution2D)         (None, 128, 27, 27)   153728      lambda_72[0][0]
# ____________________________________________________________________________________________________
# conv_2 (Merge)                   (None, 256, 27, 27)   0           conv_2_1[0][0]
#                                                                    conv_2_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_22 (MaxPooling2D)   (None, 256, 13, 13)   0           conv_2[0][0]
# ____________________________________________________________________________________________________
# lambda_73 (Lambda)               (None, 256, 13, 13)   0           maxpooling2d_22[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_42 (ZeroPadding2D) (None, 256, 15, 15)   0           lambda_73[0][0]
# ____________________________________________________________________________________________________
# conv_3 (Convolution2D)           (None, 384, 13, 13)   885120      zeropadding2d_42[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_43 (ZeroPadding2D) (None, 384, 15, 15)   0           conv_3[0][0]
# ____________________________________________________________________________________________________
# lambda_74 (Lambda)               (None, 192, 15, 15)   0           zeropadding2d_43[0][0]
# ____________________________________________________________________________________________________
# lambda_75 (Lambda)               (None, 192, 15, 15)   0           zeropadding2d_43[0][0]
# ____________________________________________________________________________________________________
# conv_4_1 (Convolution2D)         (None, 192, 13, 13)   331968      lambda_74[0][0]
# ____________________________________________________________________________________________________
# conv_4_2 (Convolution2D)         (None, 192, 13, 13)   331968      lambda_75[0][0]
# ____________________________________________________________________________________________________
# conv_4 (Merge)                   (None, 384, 13, 13)   0           conv_4_1[0][0]
#                                                                    conv_4_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_44 (ZeroPadding2D) (None, 384, 15, 15)   0           conv_4[0][0]
# ____________________________________________________________________________________________________
# lambda_76 (Lambda)               (None, 192, 15, 15)   0           zeropadding2d_44[0][0]
# ____________________________________________________________________________________________________
# lambda_77 (Lambda)               (None, 192, 15, 15)   0           zeropadding2d_44[0][0]
# ____________________________________________________________________________________________________
# conv_5_1 (Convolution2D)         (None, 128, 13, 13)   221312      lambda_76[0][0]
# ____________________________________________________________________________________________________
# conv_5_2 (Convolution2D)         (None, 128, 13, 13)   221312      lambda_77[0][0]
# ____________________________________________________________________________________________________
# conv_5 (Merge)                   (None, 256, 13, 13)   0           conv_5_1[0][0]
#                                                                    conv_5_2[0][0]
# ____________________________________________________________________________________________________
# convpool_5 (MaxPooling2D)        (None, 256, 6, 6)     0           conv_5[0][0]
# ____________________________________________________________________________________________________
# flatten (Flatten)                (None, 9216)          0           convpool_5[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 4096)          37752832    flatten[0][0]
# ____________________________________________________________________________________________________
# dropout_21 (Dropout)             (None, 4096)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 4096)          16781312    dropout_21[0][0]
# ====================================================================================================
# Total params: 56,868,224
# Trainable params: 56,868,224
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# Processing filter 0
# Filter 0 processed in 15s
# Processing filter 1
# Filter 1 processed in 15s
# Processing filter 2
# Filter 2 processed in 14s
# Processing filter 3
# Filter 3 processed in 5s
# Processing filter 4
# Filter 4 processed in 15s
# Processing filter 5
# Filter 5 processed in 15s
# Processing filter 6
# Filter 6 processed in 15s
# Processing filter 7
# Filter 7 processed in 16s
# Processing filter 8
# Filter 8 processed in 15s
# Processing filter 9
# Filter 9 processed in 15s
# Processing filter 10
# Filter 10 processed in 16s
# Processing filter 11
# Filter 11 processed in 15s
# Processing filter 12
# Filter 12 processed in 6s
# Processing filter 13
# Filter 13 processed in 15s
# Processing filter 14
# Filter 14 processed in 6s
# Processing filter 15
# Filter 15 processed in 5s
# Processing filter 16
# Filter 16 processed in 6s
# Processing filter 17
# Filter 17 processed in 19s
# Processing filter 18
# Filter 18 processed in 19s
# Processing filter 19
# Filter 19 processed in 17s
# Processing filter 20
# Filter 20 processed in 6s
# Processing filter 21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-5fcf255f2614> in <module>()
#      82
#      83     # this function returns the loss and grads given the input picture
# ---> 84     iterate = K.function([input_img], [loss, grads])
#      85
#      86     # step size for gradient ascent
#
# /home/machine/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in function(inputs, outputs, updates, **kwargs)
#     967                 msg = 'Invalid argument "%s" passed to K.function' % key
#     968                 raise ValueError(msg)
# --> 969     return Function(inputs, outputs, updates=updates, **kwargs)
#     970
#     971
#
# /home/machine/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __init__(self, inputs, outputs, updates, **kwargs)
#     953                                         allow_input_downcast=True,
#     954                                         on_unused_input='ignore',
# --> 955                                         **kwargs)
#     956
#     957     def __call__(self, inputs):
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     324                    on_unused_input=on_unused_input,
#     325                    profile=profile,
# --> 326                    output_keys=output_keys)
#     327     # We need to add the flag check_aliased inputs if we have any mutable or
#     328     # borrowed used defined inputs
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1781                    profile=profile,
#    1782                    on_unused_input=on_unused_input,
# -> 1783                    output_keys=output_keys).create(
#    1784             defaults)
#    1785
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1463                         optimizer, inputs, outputs)
#    1464                 else:
# -> 1465                     optimizer_profile = optimizer(fgraph)
#    1466
#    1467                 end_optimizer = time.time()
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in __call__(self, fgraph)
#      96
#      97         """
# ---> 98         return self.optimize(fgraph)
#      99
#     100     def add_requirements(self, fgraph):
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      85             orig = theano.tensor.basic.constant.enable
#      86             theano.tensor.basic.constant.enable = False
# ---> 87             ret = self.apply(fgraph, *args, **kwargs)
#      88         finally:
#      89             theano.tensor.basic.constant.enable = orig
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     233                 nb_nodes_before = len(fgraph.apply_nodes)
#     234                 t0 = time.time()
# --> 235                 sub_prof = optimizer.optimize(fgraph)
#     236                 l.append(float(time.time() - t0))
#     237                 sub_profs.append(sub_prof)
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      85             orig = theano.tensor.basic.constant.enable
#      86             theano.tensor.basic.constant.enable = False
# ---> 87             ret = self.apply(fgraph, *args, **kwargs)
#      88         finally:
#      89             theano.tensor.basic.constant.enable = orig
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     233                 nb_nodes_before = len(fgraph.apply_nodes)
#     234                 t0 = time.time()
# --> 235                 sub_prof = optimizer.optimize(fgraph)
#     236                 l.append(float(time.time() - t0))
#     237                 sub_profs.append(sub_prof)
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in optimize(self, fgraph, *args, **kwargs)
#      85             orig = theano.tensor.basic.constant.enable
#      86             theano.tensor.basic.constant.enable = False
# ---> 87             ret = self.apply(fgraph, *args, **kwargs)
#      88         finally:
#      89             theano.tensor.basic.constant.enable = orig
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply(self, fgraph, start_from)
#    2440                 nb = change_tracker.nb_imported
#    2441                 t_opt = time.time()
# -> 2442                 sub_prof = gopt.apply(fgraph)
#    2443                 time_opts[gopt] += time.time() - t_opt
#    2444                 sub_profs.append(sub_prof)
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/opt.pyc in apply(self, fgraph)
#     853
#     854                 try:
# --> 855                     fgraph.replace_all_validate(pairs, 'MergeOptimizer')
#     856                 except InconsistencyError:
#     857                     success = False
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/toolbox.pyc in replace_all_validate(self, fgraph, replacements, reason, verbose)
#     338         for r, new_r in replacements:
#     339             try:
# --> 340                 fgraph.replace(r, new_r, reason=reason, verbose=False)
#     341             except Exception as e:
#     342                 msg = str(e)
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/fg.pyc in replace(self, r, new_r, reason, verbose)
#     506         for node, i in list(r.clients):  # copy the client list for iteration
#     507             assert (node == 'output' and self.outputs[i] is r) or (node.inputs[i] is r)
# --> 508             self.change_input(node, i, new_r, reason=reason)
#     509
#     510         # sometimes the following is triggered.  If you understand why, please explain to James.
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/fg.pyc in change_input(self, node, i, new_r, reason)
#     455         # transaction will be reverted later.
#     456         self.execute_callbacks('on_change_input', node, i,
# --> 457                                r, new_r, reason=reason)
#     458
#     459     # replace #
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/gof/fg.pyc in execute_callbacks(self, name, *args, **kwargs)
#     586                 continue
#     587             tf0 = time.time()
# --> 588             fn(self, *args, **kwargs)
#     589             self.execute_callbacks_times[feature] += time.time() - tf0
#     590         self.execute_callbacks_time += time.time() - t0
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.pyc in on_change_input(self, fgraph, node, i, r, new_r, reason)
#    1361         # This tells us that r and new_r must have the same shape if
#    1362         # we didn't know that the shapes are related, now we do.
# -> 1363         self.update_shape(new_r, r)
#    1364
#    1365         # change_input happens in two cases:
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/tensor/opt.pyc in update_shape(self, r, other_r)
#    1225                     self.lscalar_one.equals(
#    1226                         T.extract_constant(merged_shape[i], only_process_constants=True))
# -> 1227                     for i in xrange(r.ndim)])
#    1228         self.shape_of[r] = tuple(merged_shape)
#    1229         for sv in self.shape_of[r]:
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/tensor/var.pyc in equals(self, other)
#     955             other = theano.tensor.basic.constant(other)
#     956         return (isinstance(other, TensorConstant) and
# --> 957                 self.signature() == other.signature())
#     958
#     959     def __copy__(self):
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/tensor/var.pyc in __eq__(self, other)
#     864             # False, which is why we do not bother with testing `other.has_nan`
#     865             # here).
# --> 866             return (self.sum == other.sum) and numpy.all(d0 == d1)
#     867
#     868     def __hash__(self):
#
# /home/machine/anaconda2/lib/python2.7/site-packages/theano/tensor/var.pyc in _get_sum(self)
#     879             return self._sum
#     880         except AttributeError:
# --> 881             self._sum = self.no_nan.sum()
#     882             # The following 2 lines are needede as in Python 3.3 with NumPy
#     883             # 1.7.1, numpy.ndarray and numpy.memmap aren't hashable.
#
# /home/machine/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:
